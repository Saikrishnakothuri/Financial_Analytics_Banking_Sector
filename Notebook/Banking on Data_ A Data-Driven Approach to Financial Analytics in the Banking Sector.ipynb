# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
file_path = "A Data-Driven Approach to Financial Analytics in the Banking Sector"
data = pd.read_excel("/content/A Data-Driven Approach to Financial Analytics in the Banking Sector.xlsx")

# Display basic info
print(data.info())
print(data.head())
print(data.shape)

# Gender distribution
gender_counts = data["Gender"].value_counts()
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90, colors=['lightblue', 'lightcoral'])
plt.title("Gender Distribution")
plt.axis("equal")
plt.show()

# Age Group Distribution
age_counts = data["Age"].value_counts(normalize=True) * 100
sns.barplot(x=age_counts.index, y=age_counts.values, palette="pastel")
plt.title("Age Group Distribution")
plt.ylabel("Percentage")
plt.xlabel("Age Groups")
plt.show()

#Frequency of Digital Banking Usage
usage_counts = data["2. How often do you use digital banking services (e.g., mobile banking, UPI, online transactions)?"].value_counts()
usage_counts.plot(kind="barh", color='teal', edgecolor='black')
plt.title("Frequency of Digital Banking Usage")
plt.xlabel("Count")
plt.ylabel("Usage Frequency")
plt.show()

#Primary Concerns About Banks Using Data
sns.countplot(y="5. What is your primary concern regarding banks using your financial data?", data=data, palette="viridis")
plt.title("Primary Concerns About Data Usage")
plt.show()


# Primary Concerns About Banks Using Data
#Corrected column name to match the actual column header
concern_column = "5. What is your primary concern regarding banks using your financial data?"
sns.countplot(y=concern_column, data=data, palette="viridis")
plt.title("Primary Concerns About Data Usage")
plt.show()

# Confidence in Fraud Detection Using AI
#Corrected column name to match the actual column header
confidence_column = "7. How confident are you in your bank’s ability to detect and prevent fraudulent transactions using AI?"
sns.boxplot(x=confidence_column, data=data, palette="cool")
plt.title("Confidence in Fraud Detection Using AI")
plt.xticks(rotation=45, ha="right") # Rotate x-axis labels for better readability
plt.show()

#Impact of AI on Banking Experience
ai_impact = data["9. Do you believe AI-powered banking has improved your overall banking experience?"].value_counts()
plt.pie(ai_impact, labels=ai_impact.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("coolwarm", len(ai_impact)))
plt.title("Impact of AI on Banking Experience")
plt.axis("equal")
plt.show()

#AI Impact by Gender
sns.countplot(x="9. Do you believe AI-powered banking has improved your overall banking experience?", hue="Gender", data=data, palette="husl")
plt.title("AI Banking Experience Impact by Gender")
plt.legend(title="Gender")
plt.xticks(rotation=45)
plt.show()

#AI Impact Across Age Groups
sns.countplot(x="9. Do you believe AI-powered banking has improved your overall banking experience?", hue="Age", data=data, palette="pastel")
plt.title("AI Banking Experience Impact Across Age Groups")
plt.legend(title="Age Group")
plt.xticks(rotation=45)
plt.show()

#Security Features vs Trust in Banks
sns.countplot(y="8. What additional security features would make you feel safer while using digital banking?", hue="12. Do you trust banks to handle your financial data responsibly?", data=data, palette="muted")
plt.title("Security Feature Preferences vs Trust in Banks")
plt.legend(title="Trust Level")
plt.show()

#Emerging Banking Technology Trends
technology_trends = data["16. Which emerging banking technology do you think will have the biggest impact?"].value_counts()
technology_trends.plot(kind='line', color='green', marker='o')
plt.title("Emerging Banking Technology Trends")
plt.xlabel("Technologies")
plt.ylabel("Respondent Count")
plt.xticks(rotation=45)
plt.show()

#Relation Between Security Concerns and AI Impact
sns.scatterplot(x="5. What is your primary concern regarding banks using your financial data?", y="9. Do you believe AI-powered banking has improved your overall banking experience?", data=data, hue="Gender", palette="Set2")
plt.title("Security Concerns vs AI Impact on Experience")
plt.xticks(rotation=45)
plt.show()

#Confidence in Fraud Detection by AI
sns.boxplot(x="7. How confident are you in your bank’s ability to detect and prevent fraudulent transactions using AI?", data=data, palette="cool")
plt.title("Confidence in Fraud Detection Using AI")
plt.show()

#Trust in Banks Handling Financial Data Responsibly vs Willingness to Share Data
sns.countplot(x="12. Do you trust banks to handle your financial data responsibly?", hue="10. Would you be willing to share more of your financial data if it meant better banking recommendations and security?", data=data, palette="pastel")
plt.title("Trust in Banks vs Willingness to Share Data")
plt.xticks(rotation=45)
plt.show()

#AI Awareness and Fraud Alerts
sns.countplot(x="3. Are you aware that banks use data analytics for fraud detection, risk assessment, and customer service?", hue="6. Have you ever received a fraud alert from your bank (e.g., unauthorized transaction notifications)?", data=data, palette="rocket")
plt.title("AI Awareness vs Fraud Alert Experience")
plt.xticks(rotation=45)
plt.show()

#Impact of AI-Powered Banking on Customer Experience
sns.countplot(x="9. Do you believe AI-powered banking has improved your overall banking experience?", hue="7. How confident are you in your bank’s ability to detect and prevent fraudulent transactions using AI?", data=data, palette="husl")
plt.title("AI-Powered Banking Experience vs Confidence in AI")
plt.xticks(rotation=45)
plt.show()

#Digital Banking Frequency and AI Awareness
sns.countplot(x="2. How often do you use digital banking services (e.g., mobile banking, UPI, online transactions)?", hue="3. Are you aware that banks use data analytics for fraud detection, risk assessment, and customer service?", data=data, palette="viridis")
plt.title("Digital Banking Frequency vs AI Awareness")
plt.xticks(rotation=45)
plt.legend(loc="upper right", bbox_to_anchor=(1.5, 1))
plt.show()

#Customer Feedback on Transparency Preferences
sns.countplot(x="14. Would you prefer banks to be more transparent about how they use your data for analytics?", data=data, palette="crest")
plt.title("Preferences for Data Transparency")
plt.show()

#Improvement Suggestions for Digital Banking Services
sns.countplot(y="18. What improvements would you like to see in digital banking services?", data=data, palette="dark")
plt.title("Suggestions for Improvement in Digital Banking")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 22 columns):
#  #   Column                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                           --------------  -----
#  0   Name                                                                                                                             63 non-null     object
#  1   Gender                                                                                                                           63 non-null     object
#  2   Age                                                                                                                              63 non-null     object
#  3   1.What type of banking services do you use frequently? (Select all that apply)                                                   63 non-null     object
#  4   2. How often do you use digital banking services (e.g., mobile banking, UPI, online transactions)?                               63 non-null     object
#  5   3. Are you aware that banks use data analytics for fraud detection, risk assessment, and customer service?                       63 non-null     object
#  6   4. Have you noticed personalized banking recommendations (e.g., savings insights, loan offers) based on your spending patterns?  63 non-null     object
#  7   5. What is your primary concern regarding banks using your financial data?                                                       63 non-null     object
#  8   6. Have you ever received a fraud alert from your bank (e.g., unauthorized transaction notifications)?                           63 non-null     object
#  9   7. How confident are you in your bank’s ability to detect and prevent fraudulent transactions using AI?                          63 non-null     object
#  10  8. What additional security features would make you feel safer while using digital banking?                                      63 non-null     object
#  11  9. Do you believe AI-powered banking has improved your overall banking experience?                                               63 non-null     object
#  12  10. Would you be willing to share more of your financial data if it meant better banking recommendations and security?           63 non-null     object
#  13  11. Which area of banking would you like to see improved through AI and data analytics?                                          63 non-null     object
#  14  12. Do you trust banks to handle your financial data responsibly?                                                                63 non-null     object
#  15  13. Are you aware of the financial regulations (e.g., GDPR, AML laws) that protect your banking data?                            63 non-null     object
#  16  14. Would you prefer banks to be more transparent about how they use your data for analytics?                                    63 non-null     object
#  17  15. How do you feel about AI-powered banking replacing traditional banking services?                                             63 non-null     object
#  18  16. Which emerging banking technology do you think will have the biggest impact?                                                 63 non-null     object
#  19  17. Would you be willing to participate in further research or interviews regarding this topic?                                  63 non-null     object
#  20  18. What improvements would you like to see in digital banking services?                                                         62 non-null     object
#  21  19. Any additional comments or concerns about banking data analytics?                                                            61 non-null     object
# dtypes: object(22)
# memory usage: 11.0+ KB
# None
#                    Name  Gender       Age  \
# 0      M.VIKHYATH REDDY    Male  Below 25
# 1  Sai Krishna Kothuri     Male  Below 25
# 2       Sri Sai Amruth     Male     25-30
# 3           Siddhartha     Male  Below 25
# 4              Pragathi  Female  Below 25
#
#   1.What type of banking services do you use frequently? (Select all that apply)  \
# 0  Online banking (mobile apps, web portals), ATM...
# 1          Online banking (mobile apps, web portals)
# 2          Online banking (mobile apps, web portals)
# 3          Online banking (mobile apps, web portals)
# 4          Online banking (mobile apps, web portals)
#
#   2. How often do you use digital banking services (e.g., mobile banking, UPI, online transactions)?  \
# 0                                              Daily
# 1                                              Daily
# 2                                              Daily
# 3                                              Daily
# 4                                              Daily
#
#   3. Are you aware that banks use data analytics for fraud detection, risk assessment, and customer service?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   4. Have you noticed personalized banking recommendations (e.g., savings insights, loan offers) based on your spending patterns?  \
# 0                          Yes, but I don’t use them
# 1                       Yes, and I find them helpful
# 2                       Yes, and I find them helpful
# 3                          Yes, but I don’t use them
# 4                          No, I haven’t noticed any
#
#   5. What is your primary concern regarding banks using your financial data?  \
# 0                    Privacy and data security risks
# 1                    Privacy and data security risks
# 2                    Privacy and data security risks
# 3                       No concerns, I trust my bank
# 4           Misuse of personal financial information
#
#   6. Have you ever received a fraud alert from your bank (e.g., unauthorized transaction notifications)?  \
# 0                   Yes, and it helped prevent fraud
# 1                   Yes, and it helped prevent fraud
# 2               No, and I don’t think it’s necessary
# 3                   Yes, and it helped prevent fraud
# 4              No, but I think it’s a useful feature
#
#   7. How confident are you in your bank’s ability to detect and prevent fraudulent transactions using AI?  \
# 0                                 Somewhat confident
# 1                                 Somewhat confident
# 2                                 Somewhat confident
# 3                                     Very confident
# 4                                 Somewhat confident
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   10. Would you be willing to share more of your financial data if it meant better banking recommendations and security?  \
# 0               Maybe, depending on privacy policies
# 1                  Yes, if my data remains protected
# 2               Maybe, depending on privacy policies
# 3               Maybe, depending on privacy policies
# 4               Maybe, depending on privacy policies
#
#   11. Which area of banking would you like to see improved through AI and data analytics?  \
# 0                  Better fraud detection & security
# 1                  Better fraud detection & security
# 2                  Better fraud detection & security
# 3                      Automated investment planning
# 4                      Automated investment planning
#
#   12. Do you trust banks to handle your financial data responsibly?  \
# 0                        Somewhat, but with concerns
# 1                        Somewhat, but with concerns
# 2                                    Yes, completely
# 3                        Somewhat, but with concerns
# 4                        Somewhat, but with concerns
#
#   13. Are you aware of the financial regulations (e.g., GDPR, AML laws) that protect your banking data?  \
# 0                                                 No
# 1                                                Yes
# 2                                           Not Sure
# 3                                                 No
# 4                                                 No
#
#   14. Would you prefer banks to be more transparent about how they use your data for analytics?  \
# 0                      Yes, I want full transparency
# 1                      Yes, I want full transparency
# 2                Maybe, but it’s not a major concern
# 3                      Yes, I want full transparency
# 4                Maybe, but it’s not a major concern
#
#   15. How do you feel about AI-powered banking replacing traditional banking services?  \
# 0               Neutral – A balance of both is ideal
# 1                 Excited – AI banking is the future
# 2               Neutral – A balance of both is ideal
# 3               Neutral – A balance of both is ideal
# 4               Neutral – A balance of both is ideal
#
#   16. Which emerging banking technology do you think will have the biggest impact?  \
# 0       Blockchain for secure financial transactions
# 1       Blockchain for secure financial transactions
# 2  AI-driven customer service (chatbots, virtual ...
# 3  AI-driven customer service (chatbots, virtual ...
# 4       Predictive analytics for smarter investments
#
#   17. Would you be willing to participate in further research or interviews regarding this topic?  \
# 0                                Yes, I’m interested
# 1                                Yes, I’m interested
# 2                                Yes, I’m interested
# 3                                Yes, I’m interested
# 4                                Yes, I’m interested
#
#   18. What improvements would you like to see in digital banking services?  \
# 0  The improvements I like to see is sometimes th...
# 1  Integrate finance with Blockchain Technology i...
# 2                                      Service 24hrs
# 3                 No such improvements from my side
# 4                              Data analytics and AI
#
#   19. Any additional comments or concerns about banking data analytics?
# 0                                                 No
# 1                                           Nothing
# 2             Need 24hr service (like customer care)
# 3                                                 No
# 4                                Unauthorized access
#
# [5 rows x 22 columns]
# (63, 22)
# /tmp/ipython-input-9-3398761396.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=age_counts.index, y=age_counts.values, palette="pastel")
# /tmp/ipython-input-9-3398761396.py:38: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y="5. What is your primary concern regarding banks using your financial data?", data=data, palette="viridis")
# /tmp/ipython-input-9-3398761396.py:46: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=concern_column, data=data, palette="viridis")
# /tmp/ipython-input-9-3398761396.py:53: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=confidence_column, data=data, palette="cool")
# /tmp/ipython-input-9-3398761396.py:101: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="7. How confident are you in your bank’s ability to detect and prevent fraudulent transactions using AI?", data=data, palette="cool")
# /tmp/ipython-input-9-3398761396.py:131: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="14. Would you prefer banks to be more transparent about how they use your data for analytics?", data=data, palette="crest")
# /tmp/ipython-input-9-3398761396.py:136: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y="18. What improvements would you like to see in digital banking services?", data=data, palette="dark")
